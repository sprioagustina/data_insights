# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# %%bigquery df_ga_sample --project ibento-prod
# SELECT date, visitId, if(totals.transactions > 0, 1, 0) transaction_flag
# FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`
# WHERE _TABLE_SUFFIX BETWEEN '20170101' AND '20170301'
#
# #https://console.cloud.google.com/bigquery?referrer=search&hl=es&project=ibento-prod&ws=!1m5!1m4!4m3!1sbigquery-public-data!2sgoogle_analytics_sample!3sga_sessions_20170801
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df_ga_sample['date'] = pd.to_datetime(df_ga_sample['date'])

# %%
df_ga_sample.head()
# Out:
#         date     visitId  transaction_flag
# 0 2017-01-01  1483290878                 0
# 1 2017-01-01  1483293597                 0
# 2 2017-01-01  1483292307                 0
# 3 2017-01-01  1483299786                 0
# 4 2017-01-01  1483305691                 0

# %%
df_daily = df_ga_sample.groupby('date').agg({'visitId': ['nunique'], 'transaction_flag': ['sum']})
df_daily.columns = ['sessions', 'transactions']
df_daily.reset_index(inplace=True)
df_daily.head()
# Out:
#         date  sessions  transactions
# 0 2017-01-01      1353            11
# 1 2017-01-02      1598            18
# 2 2017-01-03      2367            29
# 3 2017-01-04      2351            29
# 4 2017-01-05      2144            41

# %%
# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Scatter(x=df_daily.date, y=df_daily.sessions, name="sessions", marker_color="blue", opacity= .5),
    secondary_y=False,
)

fig.add_trace(
    go.Scatter(x=df_daily.date, y=df_daily.transactions, name="transactions"),
    secondary_y=True,
)

# Add figure title
fig.update_layout(
    title_text="Sessions & Transactions by date - Google Analytics Sample",
    legend = dict(orientation = "h",   # show entries horizontally
                     xanchor = "center",  # use center of legend as anchor
                     x = 0.8)
)

# Set x-axis title
fig.update_xaxes(title_text="date")

# Set y-axes titles
fig.update_yaxes(title_text="<b>primary</b> sessions", secondary_y=False)
fig.update_yaxes(title_text="<b>secondary</b> transactions", secondary_y=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="77595a3b-2325-4599-a773-81b1dc8a5ad1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77595a3b-2325-4599-a773-81b1dc8a5ad1")) {                    Plotly.newPlot(                        "77595a3b-2325-4599-a773-81b1dc8a5ad1",                        [{"marker":{"color":"blue"},"name":"sessions","opacity":0.5,"x":["2017-01-01T00:00:00","2017-01-02T00:00:00","2017-01-03T00:00:00","2017-01-04T00:00:00","2017-01-05T00:00:00","2017-01-06T00:00:00","2017-01-07T00:00:00","2017-01-08T00:00:00","2017-01-09T00:00:00","2017-01-10T00:00:00","2017-01-11T00:00:00","2017-01-12T00:00:00","2017-01-13T00:00:00","2017-01-14T00:00:00","2017-01-15T00:00:00","2017-01-16T00:00:00","2017-01-17T00:00:00","2017-01-18T00:00:00","2017-01-19T00:00:00","2017-01-20T00:00:00","2017-01-21T00:00:00","2017-01-22T00:00:00","2017-01-23T00:00:00","2017-01-24T00:00:00","2017-01-25T00:00:00","2017-01-26T00:00:00","2017-01-27T00:00:00","2017-01-28T00:00:00","2017-01-29T00:00:00","2017-01-30T00:00:00","2017-01-31T00:00:00","2017-02-01T00:00:00","2017-02-02T00:00:00","2017-02-03T00:00:00","2017-02-04T00:00:00","2017-02-05T00:00:00","2017-02-06T00:00:00","2017-02-07T00:00:00","2017-02-08T00:00:00","2017-02-09T00:00:00","2017-02-10T00:00:00","2017-02-11T00:00:00","2017-02-12T00:00:00","2017-02-13T00:00:00","2017-02-14T00:00:00","2017-02-15T00:00:00","2017-02-16T00:00:00","2017-02-17T00:00:00","2017-02-18T00:00:00","2017-02-19T00:00:00","2017-02-20T00:00:00","2017-02-21T00:00:00","2017-02-22T00:00:00","2017-02-23T00:00:00","2017-02-24T00:00:00","2017-02-25T00:00:00","2017-02-26T00:00:00","2017-02-27T00:00:00","2017-02-28T00:00:00","2017-03-01T00:00:00"],"y":[1353,1598,2367,2351,2144,2184,1598,1620,2266,2229,2157,2177,1937,1513,1560,1873,2366,2204,2050,2055,1665,1674,2219,3524,2930,2175,1936,1599,1794,2339,2189,2402,2314,2140,1535,1510,2207,2438,2531,2630,2156,1749,1766,2237,2335,2565,2496,2717,1732,2158,2328,2530,2430,2326,2071,1623,1625,2304,2309,2342],"type":"scatter","xaxis":"x","yaxis":"y"},{"name":"transactions","x":["2017-01-01T00:00:00","2017-01-02T00:00:00","2017-01-03T00:00:00","2017-01-04T00:00:00","2017-01-05T00:00:00","2017-01-06T00:00:00","2017-01-07T00:00:00","2017-01-08T00:00:00","2017-01-09T00:00:00","2017-01-10T00:00:00","2017-01-11T00:00:00","2017-01-12T00:00:00","2017-01-13T00:00:00","2017-01-14T00:00:00","2017-01-15T00:00:00","2017-01-16T00:00:00","2017-01-17T00:00:00","2017-01-18T00:00:00","2017-01-19T00:00:00","2017-01-20T00:00:00","2017-01-21T00:00:00","2017-01-22T00:00:00","2017-01-23T00:00:00","2017-01-24T00:00:00","2017-01-25T00:00:00","2017-01-26T00:00:00","2017-01-27T00:00:00","2017-01-28T00:00:00","2017-01-29T00:00:00","2017-01-30T00:00:00","2017-01-31T00:00:00","2017-02-01T00:00:00","2017-02-02T00:00:00","2017-02-03T00:00:00","2017-02-04T00:00:00","2017-02-05T00:00:00","2017-02-06T00:00:00","2017-02-07T00:00:00","2017-02-08T00:00:00","2017-02-09T00:00:00","2017-02-10T00:00:00","2017-02-11T00:00:00","2017-02-12T00:00:00","2017-02-13T00:00:00","2017-02-14T00:00:00","2017-02-15T00:00:00","2017-02-16T00:00:00","2017-02-17T00:00:00","2017-02-18T00:00:00","2017-02-19T00:00:00","2017-02-20T00:00:00","2017-02-21T00:00:00","2017-02-22T00:00:00","2017-02-23T00:00:00","2017-02-24T00:00:00","2017-02-25T00:00:00","2017-02-26T00:00:00","2017-02-27T00:00:00","2017-02-28T00:00:00","2017-03-01T00:00:00"],"y":[11,18,29,29,41,26,8,11,38,23,17,22,28,11,6,13,32,36,27,18,11,10,27,28,34,27,21,4,19,33,39,27,26,29,14,12,28,23,24,28,24,10,16,30,51,27,32,67,13,15,21,25,34,30,25,12,9,27,29,32],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ti ...

# %%
df_daily['conversion'] = df_daily.apply(lambda x: round(x.transactions/x.sessions, 4), axis=1)

# %%
# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Bar(x=df_daily.date, y=df_daily.sessions, name="sessions", marker_color="blue", opacity= .4),
    secondary_y=False,
)

fig.add_trace(
    go.Scatter(x=df_daily.date, y=df_daily.conversion, name="conversion", marker_color="green"),
    secondary_y=True,
)

# Add figure title
fig.update_layout(
    title_text="Sessions & Conversion Rate by date - Google Analytics Sample",
    legend = dict(orientation = "h",   # show entries horizontally
                     xanchor = "center",  # use center of legend as anchor
                     x = 0.8)
)

# Set x-axis title
fig.update_xaxes(title_text="date")

# Set y-axes titles
fig.update_yaxes(title_text="<b>primary</b> sessions", secondary_y=False)
fig.update_yaxes(title_text="<b>secondary</b> conversion", secondary_y=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="31afc5fd-04d5-472c-b3da-fe8fead2180d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31afc5fd-04d5-472c-b3da-fe8fead2180d")) {                    Plotly.newPlot(                        "31afc5fd-04d5-472c-b3da-fe8fead2180d",                        [{"marker":{"color":"blue"},"name":"sessions","opacity":0.4,"x":["2017-01-01T00:00:00","2017-01-02T00:00:00","2017-01-03T00:00:00","2017-01-04T00:00:00","2017-01-05T00:00:00","2017-01-06T00:00:00","2017-01-07T00:00:00","2017-01-08T00:00:00","2017-01-09T00:00:00","2017-01-10T00:00:00","2017-01-11T00:00:00","2017-01-12T00:00:00","2017-01-13T00:00:00","2017-01-14T00:00:00","2017-01-15T00:00:00","2017-01-16T00:00:00","2017-01-17T00:00:00","2017-01-18T00:00:00","2017-01-19T00:00:00","2017-01-20T00:00:00","2017-01-21T00:00:00","2017-01-22T00:00:00","2017-01-23T00:00:00","2017-01-24T00:00:00","2017-01-25T00:00:00","2017-01-26T00:00:00","2017-01-27T00:00:00","2017-01-28T00:00:00","2017-01-29T00:00:00","2017-01-30T00:00:00","2017-01-31T00:00:00","2017-02-01T00:00:00","2017-02-02T00:00:00","2017-02-03T00:00:00","2017-02-04T00:00:00","2017-02-05T00:00:00","2017-02-06T00:00:00","2017-02-07T00:00:00","2017-02-08T00:00:00","2017-02-09T00:00:00","2017-02-10T00:00:00","2017-02-11T00:00:00","2017-02-12T00:00:00","2017-02-13T00:00:00","2017-02-14T00:00:00","2017-02-15T00:00:00","2017-02-16T00:00:00","2017-02-17T00:00:00","2017-02-18T00:00:00","2017-02-19T00:00:00","2017-02-20T00:00:00","2017-02-21T00:00:00","2017-02-22T00:00:00","2017-02-23T00:00:00","2017-02-24T00:00:00","2017-02-25T00:00:00","2017-02-26T00:00:00","2017-02-27T00:00:00","2017-02-28T00:00:00","2017-03-01T00:00:00"],"y":[1353,1598,2367,2351,2144,2184,1598,1620,2266,2229,2157,2177,1937,1513,1560,1873,2366,2204,2050,2055,1665,1674,2219,3524,2930,2175,1936,1599,1794,2339,2189,2402,2314,2140,1535,1510,2207,2438,2531,2630,2156,1749,1766,2237,2335,2565,2496,2717,1732,2158,2328,2530,2430,2326,2071,1623,1625,2304,2309,2342],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"green"},"name":"conversion","x":["2017-01-01T00:00:00","2017-01-02T00:00:00","2017-01-03T00:00:00","2017-01-04T00:00:00","2017-01-05T00:00:00","2017-01-06T00:00:00","2017-01-07T00:00:00","2017-01-08T00:00:00","2017-01-09T00:00:00","2017-01-10T00:00:00","2017-01-11T00:00:00","2017-01-12T00:00:00","2017-01-13T00:00:00","2017-01-14T00:00:00","2017-01-15T00:00:00","2017-01-16T00:00:00","2017-01-17T00:00:00","2017-01-18T00:00:00","2017-01-19T00:00:00","2017-01-20T00:00:00","2017-01-21T00:00:00","2017-01-22T00:00:00","2017-01-23T00:00:00","2017-01-24T00:00:00","2017-01-25T00:00:00","2017-01-26T00:00:00","2017-01-27T00:00:00","2017-01-28T00:00:00","2017-01-29T00:00:00","2017-01-30T00:00:00","2017-01-31T00:00:00","2017-02-01T00:00:00","2017-02-02T00:00:00","2017-02-03T00:00:00","2017-02-04T00:00:00","2017-02-05T00:00:00","2017-02-06T00:00:00","2017-02-07T00:00:00","2017-02-08T00:00:00","2017-02-09T00:00:00","2017-02-10T00:00:00","2017-02-11T00:00:00","2017-02-12T00:00:00","2017-02-13T00:00:00","2017-02-14T00:00:00","2017-02-15T00:00:00","2017-02-16T00:00:00","2017-02-17T00:00:00","2017-02-18T00:00:00","2017-02-19T00:00:00","2017-02-20T00:00:00","2017-02-21T00:00:00","2017-02-22T00:00:00","2017-02-23T00:00:00","2017-02-24T00:00:00","2017-02-25T00:00:00","2017-02-26T00:00:00","2017-02-27T00:00:00","2017-02-28T00:00:00","2017-03-01T00:00:00"],"y":[0.0081,0.0113,0.0123,0.0123,0.0191,0.0119,0.005,0.0068,0.0168,0.0103,0.0079,0.0101,0.0145,0.0073,0.0038,0.0069,0.0135,0.0163,0.0132,0.0088,0.0066,0.006,0.0122,0.0079,0.0116,0.0124,0.0108,0.0025,0.0106,0.0141,0.0178,0.0112,0.0112,0.0136,0.0091,0.0079,0.0127,0.0094,0.0095,0.0106,0.0111,0.0057,0.0091,0.0134,0.0218,0.0105,0.0128,0 ...

# %%
df_daily.describe()
# Out:
#          sessions  transactions  conversion
# count    60.00000          60.0   60.000000
# mean   2119.20000         23.95    0.010938
# std     399.33117     11.216551    0.004065
# min    1353.00000           4.0    0.002500
# 25%    1761.75000         14.75    0.007900
# 50%    2180.50000          25.5    0.010950
# 75%    2339.75000          29.0    0.012825
# max    3524.00000          67.0    0.024700
